# %%
import pandas as pd
import numpy as np

l = ["1996", "1997", "1998", "1999", "2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009",\
    "2010", "2011", "2012", "2013"]
l2 = ["14-15", "16-17"]

l_files = []
for i in range (0,len(l)):
    l_files.append("C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/\
Óbitos {0} GE sexo concelho.csv".format(l[i]))

l_files2 = []

for i in range (0,len(l2)):
    l_files2.append("C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/\
Óbitos {0} GE sexo concelho.csv".format(l2[i]))

x=0
for i in l_files: 
    um_ano(i).to_csv("C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Novos/Obitos_idade{0}.csv".format(l[x]),\
                  sep=';', encoding='ANSI', index=True, header=True)
    x+=1
    print (i)

x=0   
for i in l_files2: 
    n_anos(i).to_csv("C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Novos/Obitos_idade{0}.csv".format(l2[x]),\
                  sep=';', encoding='ANSI', index=True, header=True)
    x+=1
    print (i)
# Out:
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 1996 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 1997 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 1998 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 1999 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 2000 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 2001 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 2002 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 2003 GE sexo concelho.csv
# C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/Óbitos 2004 GE sexo concelho.csv
# ...

# %%
# nome_arquivo = "C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/\
# Óbitos {0} GE sexo concelho.csv".format("16-17")
# # df=urso(nome_arquivo)

def n_anos (nome_arquivo):

    df = pd.read_csv(nome_arquivo, encoding="ANSI", engine='python', sep = ";", header = 0, skiprows=9)
    l =['ano', 'code']
    for i in range (2,len(df.columns)): 
            if i < (len(df.columns))/2:
                l.append("H_" + str(df.iloc[0,i]))
            else: 
                l.append("M_" + str(df.iloc[0,i]))
    df.columns = l
    l = None

    df = df.iloc[2:,]
    df = df.iloc[:708,]
    df['code'], df['nome'] = df.iloc[:,1].str.split(':').str
    df.index = df ['code']
    df.drop(['M_nan', 'code'], inplace = True, axis = 1) 
    anos = list(df.ano.unique())
    anos = np.delete (anos,1)
    for i in range(int(len(df.index))):
        if i < (len(df.index)/len(anos)):
            df.iloc[i,0] = anos[0]
        elif i < (len(df.index)/len(anos))*2:
            df.iloc[i,0] = anos[1]
        else:
            df.iloc[i,0] = anos[2]

    l_index = []
    for i in df.index:
        if len(i) > 4: 
            l_index.append(i[3:])
        else: 
            l_index.append(i)
    df.index = l_index

    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    df = df[cols]
    df.index.name = 'code'
    return(df)

# %%
import pandas as pd
import numpy as np

# nome_arquivo = "C:/Users/jwolf/Google Drive/00_Getin/04_Programação/Originais/Obitos/\
# Óbitos {0} GE sexo concelho.csv".format("1999")

def um_ano (nome_arquivo):
    df = pd.read_csv(nome_arquivo, encoding="ANSI", engine='python', sep = ";", header = 0, skiprows=9)
    l =['ano', 'code']
    for i in range (2,len(df.columns)): 
            if i < (len(df.columns))/2:
                l.append("H_" + str(df.iloc[0,i]))
            else: 
                l.append("M_" + str(df.iloc[0,i]))
    df.columns = l
    l = None

    df = df.iloc[2:,]
    df = df.iloc[:359,]
    df
    df['code'], df['nome'] = df.iloc[:,1].str.split(':').str
    df.index = df ['code']
    df.drop(['M_nan', 'code'], inplace = True, axis = 1) 
    anos = list(df.ano.unique())
    anos = np.delete (anos,1)
 
    for i in range(int(len(df.index))):
        if i < (len(df.index)/len(anos)):
            df.iloc[i,0] = anos[0]
        elif i < (len(df.index)/len(anos))*2:
            df.iloc[i,0] = anos[1]
        else:
            df.iloc[i,0] = anos[2]

    l_index = []
    for i in df.index:
        if len(i) > 4: 
            l_index.append(i[3:])
        else: 
            l_index.append(i)
    df.index = l_index

    cols = df.columns.tolist()
    cols = cols[-1:] + cols[:-1]
    df = df[cols]
    df.index.name = 'code'
    return(df)
